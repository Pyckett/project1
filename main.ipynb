# %%
from stock_ledger import stock_ledger

def main():
    my_stock_ledger = stock_ledger()
    print("---- Stock Ledger ----")
    my_stock_ledger.buy("AAPL", 3, 150)
    my_stock_ledger.buy("AAPL", 2, 170)
    my_stock_ledger.buy("MSFT", 4, 120)
    my_stock_ledger.sell("TSLA", 2, 135)
    my_stock_ledger.display_ledger()

if __name__ == "__main__":
    main()
# Out:
# ---- Stock Ledger ----
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 13
#      10     my_stock_ledger.display_ledger()
#      12 if __name__ == "__main__":
# ---> 13     main()
#
# Cell In[7], line 9, in main()
#       7 my_stock_ledger.buy("AAPL", 2, 170)
#       8 my_stock_ledger.buy("MSFT", 4, 120)
# ----> 9 my_stock_ledger.sell("TSLA", 2, 135)
#      10 my_stock_ledger.display_ledger()
#
# AttributeError: 'stock_ledger' object has no attribute 'sell'
