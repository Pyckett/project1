# %%
from stock_ledger import stock_ledger

def main():
    my_stock_ledger = stock_ledger()
    my_stock_ledger.buy("AAPL", 20, 45)
    my_stock_ledger.buy("AAPL", 20, 75)
    my_stock_ledger.buy("MSFT", 20, 95)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("AAPL", 30, 65)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("AAPL", 10, 65)
    my_stock_ledger.display_ledger()

    my_stock_ledger.buy("AAPL", 100, 20)
    my_stock_ledger.buy("AAPL", 20, 24)
    my_stock_ledger.buy("TSLA", 200, 36)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("AAPL", 10, 65)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("TSLA", 150, 30)
    my_stock_ledger.display_ledger()

    my_stock_ledger.buy("MSFT", 5, 60)
    my_stock_ledger.buy("MSFT", 5, 70)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("MSFT", 4, 30)
    my_stock_ledger.display_ledger()

    my_stock_ledger.sell("MSFT", 2, 30)
    my_stock_ledger.display_ledger()

if __name__ == "__main__":
    main()
# Out:
# ---- Stock Ledger ----
# AAPL: 45.0 (20 shares), 75.0 (20 shares)
# MSFT: 95.0 (20 shares)
#
# ---- Stock Ledger ----
# AAPL: 75.0 (10 shares)
# MSFT: 95.0 (20 shares)
#
# ---- Stock Ledger ----
# AAPL: No shares
# MSFT: 95.0 (20 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (100 shares), 24.0 (20 shares)
# MSFT: 95.0 (20 shares)
# TSLA: 36.0 (200 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares)
# MSFT: 95.0 (20 shares)
# TSLA: 36.0 (200 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares)
# MSFT: 95.0 (20 shares)
# TSLA: 36.0 (50 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares)
# MSFT: 95.0 (20 shares), 60.0 (5 shares), 70.0 (5 shares)
# TSLA: 36.0 (50 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares)
# MSFT: 95.0 (16 shares), 60.0 (5 shares), 70.0 (5 shares)
# TSLA: 36.0 (50 shares)
#
# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares)
# ...
